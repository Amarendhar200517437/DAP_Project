# %% [markdown]
# # Exploratory Data Analysis

# %%
# importing required modules for EDA process

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Step-1

# %%
# Read the data

# %%
df = pd.read_csv('C:\\Users\\amare\OneDrive\Desktop\datasets\prices.csv')

# %%
df.head()
# Out:
#    REF_DATE     GEO           DGUID          Prices  \
# 0      2007  Canada  2016A000011124  Current prices
# 1      2007  Canada  2016A000011124  Current prices
# 2      2007  Canada  2016A000011124  Current prices
# 3      2007  Canada  2016A000011124  Current prices
# 4      2007  Canada  2016A000011124  Current prices
#
#                                    Estimates      UOM  UOM_ID SCALAR_FACTOR  \
# 0    Household final consumption expenditure  Dollars      81      millions
# 1           Food and non-alcoholic beverages  Dollars      81      millions
# 2                                       Food  Dollars      81      millions
# 3                    Non-alcoholic beverages  Dollars      81      millions
# 4  Alcoholic beverages, tobacco and cannabis  Dollars      81      millions
#
#    SCALAR_ID     VECTOR COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  \
# 0          6  v62783881      1.1.1  842029.0    NaN     NaN         NaN
# ...

# %%
df.tail()
# Out:
#        REF_DATE      GEO        DGUID          Prices  \
# 22880      2020  Nunavut  2016A000262  Current prices
# 22881      2020  Nunavut  2016A000262  Current prices
# 22882      2020  Nunavut  2016A000262  Current prices
# 22883      2020  Nunavut  2016A000262  Current prices
# 22884      2020  Nunavut  2016A000262  Current prices
#
#                                                Estimates      UOM  UOM_ID  \
# 22880                             Net expenditure abroad  Dollars      81
# 22881                    Expenditure by Canadians abroad  Dollars      81
# 22882  Expenditure by Canadians in other provinces or...  Dollars      81
# 22883             Expenditure by non-residents in Canada  Dollars      81
# 22884  Expenditure by Canadians residing in other pro...  Dollars      81
#
#       SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# 22880      millions          6  v62786900   14.1.108   13.4    NaN     NaN
# ...

# %%
df.shape
# Out:
# (22885, 16)

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Prices', 'Estimates', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df.nunique(axis=0)
# Out:
# REF_DATE            14
# GEO                 15
# DGUID               14
# Prices               1
# Estimates          115
# UOM                  1
# UOM_ID               1
# SCALAR_FACTOR        1
# SCALAR_ID            1
# VECTOR            1725
# COORDINATE        1725
# VALUE            11551
# STATUS               1
# SYMBOL               0
# TERMINATED           0
# DECIMALS             1
# dtype: int64

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#            REF_DATE        UOM_ID     SCALAR_ID           VALUE    SYMBOL  \
# count  22885.000000  22885.000000  22885.000000    22386.000000  0.000000
# mean    2013.582915     81.000000      6.000000     3990.592687       nan
# std        4.057703      0.000000      0.000000    31956.674839       nan
# min     2007.000000     81.000000      6.000000   -44323.000000       nan
# 25%     2010.000000     81.000000      6.000000       22.500000       nan
# 50%     2014.000000     81.000000      6.000000      188.100000       nan
# 75%     2017.000000     81.000000      6.000000     1236.150000       nan
# max     2020.000000     81.000000      6.000000  1299544.000000       nan
#
#       TERMINATED      DECIMALS
# count   0.000000  22885.000000
# mean         nan      1.000000
# std          nan      0.000000
# min          nan      1.000000
# 25%          nan      1.000000
# 50%          nan      1.000000
# 75%          nan      1.000000
# max          nan      1.000000

# %%
# Step-2

# %%
# Remove null values and unnecessary attributes

# %%
missing_values = [0]
df = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\prices.csv", na_values = missing_values)

# %%
 to_drop = ['Prices','SCALAR_ID',
           'VECTOR',
           'COORDINATE',
           'STATUS',
           'SYMBOL',
           'TERMINATED',
           'DECIMALS',
           'UOM',
           'UOM_ID',
           'SCALAR_FACTOR']

df.drop(to_drop, inplace=True, axis=1)

# %%
df
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2007   Canada  2016A000011124
# 1          2007   Canada  2016A000011124
# 2          2007   Canada  2016A000011124
# 3          2007   Canada  2016A000011124
# 4          2007   Canada  2016A000011124
# ...         ...      ...             ...
# 22880      2020  Nunavut     2016A000262
# 22881      2020  Nunavut     2016A000262
# 22882      2020  Nunavut     2016A000262
# 22883      2020  Nunavut     2016A000262
# 22884      2020  Nunavut     2016A000262
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...

# %%
prices = df

# %%
prices
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2007   Canada  2016A000011124
# 1          2007   Canada  2016A000011124
# 2          2007   Canada  2016A000011124
# 3          2007   Canada  2016A000011124
# 4          2007   Canada  2016A000011124
# ...         ...      ...             ...
# 22880      2020  Nunavut     2016A000262
# 22881      2020  Nunavut     2016A000262
# 22882      2020  Nunavut     2016A000262
# 22883      2020  Nunavut     2016A000262
# 22884      2020  Nunavut     2016A000262
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...

# %%
prices.isnull().sum()
# Out:
# REF_DATE       0
# GEO            0
# DGUID        345
# Estimates      0
# VALUE        608
# dtype: int64

# %%
df1 = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv")

# %%
df1
# Out:
#        REF_DATE     GEO           DGUID  Provincial Sales Tax (PST)  \
# 0        2007.0  Canada  2016A000011124                     21569.3
# 1        2007.0  Canada  2016A000011124                       647.1
# 2        2007.0  Canada  2016A000011124                       432.9
# 3        2007.0  Canada  2016A000011124                       214.2
# 4        2007.0  Canada  2016A000011124                      1334.8
# ...         ...     ...             ...                         ...
# 22880       NaN     NaN             NaN                         NaN
# 22881       NaN     NaN             NaN                         NaN
# 22882       NaN     NaN             NaN                         NaN
# 22883       NaN     NaN             NaN                         NaN
# 22884       NaN     NaN             NaN                         NaN
#
#        Excluding sales taxes  Goods and Services Tax (GST)  \
# 0                   796476.3                       23982.4
# ...

# %%
df1.shape
# Out:
# (22885, 17)

# %%
df1.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Provincial Sales Tax (PST)',
#        'Excluding sales taxes', 'Goods and Services Tax (GST)', 'Estimates',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df1.nunique(axis=0)
# Out:
# REF_DATE                           14
# GEO                                14
# DGUID                              14
# Provincial Sales Tax (PST)       3148
# Excluding sales taxes           11436
# Goods and Services Tax (GST)     2955
# Estimates                         115
# UOM                                 1
# UOM_ID                              1
# SCALAR_FACTOR                       1
# SCALAR_ID                           1
# VECTOR                           1610
# COORDINATE                       1610
# STATUS                              1
# SYMBOL                              0
# TERMINATED                          0
# DECIMALS                            1
# dtype: int64

# %%
df1.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#            REF_DATE Provincial Sales Tax (PST) Excluding sales taxes  \
# count  22540.000000               22386.000000          22386.000000
# mean    2013.500000                 118.230966           3781.274748
# std        4.031218                 991.129493          30343.770282
# min     2007.000000                   0.000000         -44323.000000
# 25%     2010.000000                   0.000000             20.800000
# 50%     2013.500000                   0.800000            176.300000
# 75%     2017.000000                  22.700000           1151.550000
# max     2020.000000               40382.300000        1230282.700000
#
#       Goods and Services Tax (GST)        UOM_ID     SCALAR_ID    SYMBOL  \
# count                 22386.000000  22540.000000  22540.000000  0.000000
# mean                     91.087099     81.000000      6.000000       nan
# std                     727.025848      0.000000      0.000000       nan
# ...

# %%
missing_values = [0]
df1 = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv", na_values = missing_values)

# %%
 to_drop = ['SCALAR_ID',
           'VECTOR',
           'COORDINATE',
           'STATUS',
           'SYMBOL',
           'TERMINATED',
            'UOM',
           'DECIMALS',
           'UOM_ID',
           'SCALAR_FACTOR']

df1.drop(to_drop, inplace=True, axis=1)

# %%
df1
# Out:
#        REF_DATE     GEO           DGUID  Provincial Sales Tax (PST)  \
# 0        2007.0  Canada  2016A000011124                     21569.3
# 1        2007.0  Canada  2016A000011124                       647.1
# 2        2007.0  Canada  2016A000011124                       432.9
# 3        2007.0  Canada  2016A000011124                       214.2
# 4        2007.0  Canada  2016A000011124                      1334.8
# ...         ...     ...             ...                         ...
# 22880       NaN     NaN             NaN                         NaN
# 22881       NaN     NaN             NaN                         NaN
# 22882       NaN     NaN             NaN                         NaN
# 22883       NaN     NaN             NaN                         NaN
# 22884       NaN     NaN             NaN                         NaN
#
#        Excluding sales taxes  Goods and Services Tax (GST)  \
# 0                   796476.3                       23982.4
# ...

# %%
taxes = df1

# %%
taxes.isnull().sum()
# Out:
# REF_DATE                          345
# GEO                               345
# DGUID                             345
# Provincial Sales Tax (PST)      10702
# Excluding sales taxes             610
# Goods and Services Tax (GST)     5364
# Estimates                           0
# dtype: int64

# %%
taxes
# Out:
#        REF_DATE     GEO           DGUID  Provincial Sales Tax (PST)  \
# 0        2007.0  Canada  2016A000011124                     21569.3
# 1        2007.0  Canada  2016A000011124                       647.1
# 2        2007.0  Canada  2016A000011124                       432.9
# 3        2007.0  Canada  2016A000011124                       214.2
# 4        2007.0  Canada  2016A000011124                      1334.8
# ...         ...     ...             ...                         ...
# 22880       NaN     NaN             NaN                         NaN
# 22881       NaN     NaN             NaN                         NaN
# 22882       NaN     NaN             NaN                         NaN
# 22883       NaN     NaN             NaN                         NaN
# 22884       NaN     NaN             NaN                         NaN
#
#        Excluding sales taxes  Goods and Services Tax (GST)  \
# 0                   796476.3                       23982.4
# ...

# %%
prices
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2007   Canada  2016A000011124
# 1          2007   Canada  2016A000011124
# 2          2007   Canada  2016A000011124
# 3          2007   Canada  2016A000011124
# 4          2007   Canada  2016A000011124
# ...         ...      ...             ...
# 22880      2020  Nunavut     2016A000262
# 22881      2020  Nunavut     2016A000262
# 22882      2020  Nunavut     2016A000262
# 22883      2020  Nunavut     2016A000262
# 22884      2020  Nunavut     2016A000262
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...

# %%
# Merged two datasets

# %%
final = pd.merge(prices, taxes, on=["REF_DATE","GEO","DGUID","Estimates"])

# %%
final
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2007   Canada  2016A000011124
# 1          2007   Canada  2016A000011124
# 2          2007   Canada  2016A000011124
# 3          2007   Canada  2016A000011124
# 4          2007   Canada  2016A000011124
# ...         ...      ...             ...
# 22535      2020  Nunavut     2016A000262
# 22536      2020  Nunavut     2016A000262
# 22537      2020  Nunavut     2016A000262
# 22538      2020  Nunavut     2016A000262
# 22539      2020  Nunavut     2016A000262
#
#                                                Estimates     VALUE  \
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...

# %%
# Renamed few columns into understandable form

# %%
final = final.rename(columns = {"REF_DATE":"Year","GEO":"Location", "VALUE":"Price"})

# %%
final
# Out:
#        Year Location           DGUID  \
# 0      2007   Canada  2016A000011124
# 1      2007   Canada  2016A000011124
# 2      2007   Canada  2016A000011124
# 3      2007   Canada  2016A000011124
# 4      2007   Canada  2016A000011124
# ...     ...      ...             ...
# 22535  2020  Nunavut     2016A000262
# 22536  2020  Nunavut     2016A000262
# 22537  2020  Nunavut     2016A000262
# 22538  2020  Nunavut     2016A000262
# 22539  2020  Nunavut     2016A000262
#
#                                                Estimates     Price  \
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...                                                  ...       ...
# ...

# %%
final.isnull().sum()
# Out:
# Year                                0
# Location                            0
# DGUID                               0
# Estimates                           0
# Price                             263
# Provincial Sales Tax (PST)      10357
# Excluding sales taxes             265
# Goods and Services Tax (GST)     5019
# dtype: int64

# %%
final.describe()
# Out:
#                Year         Price  Provincial Sales Tax (PST)  \
# count  22540.000000  2.227700e+04                12183.000000
# mean    2013.500000  4.010118e+03                  217.246852
# std        4.031218  3.203354e+04                 1335.507089
# min     2007.000000 -4.432300e+04                    0.100000
# 25%     2010.000000  2.360000e+01                    3.500000
# 50%     2013.500000  1.918000e+02                   17.400000
# 75%     2017.000000  1.247300e+03                   83.400000
# max     2020.000000  1.299544e+06                40382.300000
#
#        Excluding sales taxes  Goods and Services Tax (GST)
# count           2.227500e+04                  17521.000000
# mean            3.800117e+03                    116.378962
# std             3.041811e+04                    819.998015
# min            -4.432300e+04                      0.100000
# 25%             2.180000e+01                      1.100000
# ...

# %%
final = final.fillna((0))

# %%
final.isnull().sum()
# Out:
# Year                            0
# Location                        0
# DGUID                           0
# Estimates                       0
# Price                           0
# Provincial Sales Tax (PST)      0
# Excluding sales taxes           0
# Goods and Services Tax (GST)    0
# dtype: int64

# %%
final
# Out:
#        Year Location           DGUID  \
# 0      2007   Canada  2016A000011124
# 1      2007   Canada  2016A000011124
# 2      2007   Canada  2016A000011124
# 3      2007   Canada  2016A000011124
# 4      2007   Canada  2016A000011124
# ...     ...      ...             ...
# 22535  2020  Nunavut     2016A000262
# 22536  2020  Nunavut     2016A000262
# 22537  2020  Nunavut     2016A000262
# 22538  2020  Nunavut     2016A000262
# 22539  2020  Nunavut     2016A000262
#
#                                                Estimates     Price  \
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...                                                  ...       ...
# ...

# %%
# Created a new attribute 'Total' by adding the values of ['Price', 'PST', 'EST', 'GST'] columns

# %%
Total = final['Price'] + final['Provincial Sales Tax (PST)'] + final['Excluding sales taxes'] + final['Goods and Services Tax (GST)']

# %%
Total
# Out:
# 0        1684057.0
# 1         150463.9
# 2         133074.0
# 3          17390.0
# 4          69318.0
#            ...
# 22535         26.8
# 22536         18.6
# 22537         16.2
# 22538         -1.0
# 22539         -7.0
# Length: 22540, dtype: float64

# %%
final.assign(Total = Total)
# Out:
#        Year Location           DGUID  \
# 0      2007   Canada  2016A000011124
# 1      2007   Canada  2016A000011124
# 2      2007   Canada  2016A000011124
# 3      2007   Canada  2016A000011124
# 4      2007   Canada  2016A000011124
# ...     ...      ...             ...
# 22535  2020  Nunavut     2016A000262
# 22536  2020  Nunavut     2016A000262
# 22537  2020  Nunavut     2016A000262
# 22538  2020  Nunavut     2016A000262
# 22539  2020  Nunavut     2016A000262
#
#                                                Estimates     Price  \
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# 3                                Non-alcoholic beverages    8695.0
# 4              Alcoholic beverages, tobacco and cannabis   34659.0
# ...                                                  ...       ...
# ...

# %%
# Step-3

# %%
# Finding Correlation

# %%
final.corr()
# Out:
#                                   Year     Price  Provincial Sales Tax (PST)  \
# Year                          1.000000  0.016971                    0.022429
# Price                         0.016971  1.000000                    0.935915
# Provincial Sales Tax (PST)    0.022429  0.935915                    1.000000
# Excluding sales taxes         0.016874  0.999836                    0.929580
# Goods and Services Tax (GST)  0.011104  0.949458                    0.977503
#
#                               Excluding sales taxes  \
# Year                                       0.016874
# Price                                      0.999836
# Provincial Sales Tax (PST)                 0.929580
# Excluding sales taxes                      1.000000
# Goods and Services Tax (GST)               0.944038
#
#                               Goods and Services Tax (GST)
# Year                                              0.011104
# Price                                             0.949458
# ...

# %%
sns.heatmap(final.corr(), annot=True)
plt.show()

# %%
sns.pairplot(final)

# %%
sns.relplot(x = 'Year', y = 'Provincial Sales Tax (PST)', hue = 'Location', data=final)

# %%
sns.relplot(x = 'Year', y = 'Excluding sales taxes', hue = 'Location', data=final)

# %%
sns.relplot(x = 'Year', y = 'Goods and Services Tax (GST)', hue = 'Location', data=final)

# %%
sns.relplot(x = 'Year', y = 'Price', hue = 'Location', data=final)

# %%
sns.distplot(final['Provincial Sales Tax (PST)'])
# Out:
# C:\Users\amare\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Provincial Sales Tax (PST)', ylabel='Density'>

# %%
sns.distplot(final['Excluding sales taxes'])
# Out:
# C:\Users\amare\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Excluding sales taxes', ylabel='Density'>

# %%
sns.distplot(final['Goods and Services Tax (GST)'])
# Out:
# C:\Users\amare\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Goods and Services Tax (GST)', ylabel='Density'>

# %%
sns.distplot(final['Price'])
# Out:
# C:\Users\amare\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.catplot(x='Provincial Sales Tax (PST)', kind='box', data=final)

# %%
sns.catplot(x='Excluding sales taxes', kind='box', data=final)

# %%
sns.catplot(x='Goods and Services Tax (GST)', kind='box', data=final)

# %%
sns.catplot(x='Price', kind='box', data=final)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = final.drop(['DGUID'], axis=1)
test = final['Total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
final = plt.subplot(2,2,2, figsize=(10,4))

# %%
X_train, X_test, y_train, y_test = train_test_split(test, test_size = 0.3, random_state = 2)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
