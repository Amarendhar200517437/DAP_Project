# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\amare\OneDrive\Desktop\datasets\prices.csv')

# %%
df.head()
# Out:
#    REF_DATE     GEO           DGUID          Prices  \
# 0      2007  Canada  2016A000011124  Current prices
# 1      2007  Canada  2016A000011124  Current prices
# 2      2007  Canada  2016A000011124  Current prices
# 3      2007  Canada  2016A000011124  Current prices
# 4      2007  Canada  2016A000011124  Current prices
#
#                                    Estimates      UOM  UOM_ID SCALAR_FACTOR  \
# 0    Household final consumption expenditure  Dollars      81      millions
# 1           Food and non-alcoholic beverages  Dollars      81      millions
# 2                                       Food  Dollars      81      millions
# 3                    Non-alcoholic beverages  Dollars      81      millions
# 4  Alcoholic beverages, tobacco and cannabis  Dollars      81      millions
#
#    SCALAR_ID     VECTOR COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  \
# 0          6  v62783881      1.1.1  842029.0    NaN     NaN         NaN
# ...

# %%
df.tail()
# Out:
#        REF_DATE      GEO        DGUID          Prices  \
# 22880      2020  Nunavut  2016A000262  Current prices
# 22881      2020  Nunavut  2016A000262  Current prices
# 22882      2020  Nunavut  2016A000262  Current prices
# 22883      2020  Nunavut  2016A000262  Current prices
# 22884      2020  Nunavut  2016A000262  Current prices
#
#                                                Estimates      UOM  UOM_ID  \
# 22880                             Net expenditure abroad  Dollars      81
# 22881                    Expenditure by Canadians abroad  Dollars      81
# 22882  Expenditure by Canadians in other provinces or...  Dollars      81
# 22883             Expenditure by non-residents in Canada  Dollars      81
# 22884  Expenditure by Canadians residing in other pro...  Dollars      81
#
#       SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# 22880      millions          6  v62786900   14.1.108   13.4    NaN     NaN
# ...

# %%
df.shape
# Out:
# (22885, 16)

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Prices', 'Estimates', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
df.nunique(axis=0)
# Out:
# REF_DATE            14
# GEO                 15
# DGUID               14
# Prices               1
# Estimates          115
# UOM                  1
# UOM_ID               1
# SCALAR_FACTOR        1
# SCALAR_ID            1
# VECTOR            1725
# COORDINATE        1725
# VALUE            11551
# STATUS               1
# SYMBOL               0
# TERMINATED           0
# DECIMALS             1
# dtype: int64

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#            REF_DATE        UOM_ID     SCALAR_ID           VALUE    SYMBOL  \
# count  22885.000000  22885.000000  22885.000000    22386.000000  0.000000
# mean    2013.582915     81.000000      6.000000     3990.592687       nan
# std        4.057703      0.000000      0.000000    31956.674839       nan
# min     2007.000000     81.000000      6.000000   -44323.000000       nan
# 25%     2010.000000     81.000000      6.000000       22.500000       nan
# 50%     2014.000000     81.000000      6.000000      188.100000       nan
# 75%     2017.000000     81.000000      6.000000     1236.150000       nan
# max     2020.000000     81.000000      6.000000  1299544.000000       nan
#
#       TERMINATED      DECIMALS
# count   0.000000  22885.000000
# mean         nan      1.000000
# std          nan      0.000000
# min          nan      1.000000
# 25%          nan      1.000000
# 50%          nan      1.000000
# 75%          nan      1.000000
# max          nan      1.000000

# %%
missing_values = [0]
df = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\prices.csv", na_values = missing_values)

# %%
 to_drop = ['SCALAR_ID',
           'VECTOR',
           'COORDINATE',
           'STATUS',
           'SYMBOL',
           'TERMINATED',
           'DECIMALS',
           'UOM',
           'UOM_ID',
           'SCALAR_FACTOR']

df.drop(to_drop, inplace=True, axis=1)

# %%
df
# Out:
#        REF_DATE      GEO           DGUID          Prices  \
# 0          2007   Canada  2016A000011124  Current prices
# 1          2007   Canada  2016A000011124  Current prices
# 2          2007   Canada  2016A000011124  Current prices
# 3          2007   Canada  2016A000011124  Current prices
# 4          2007   Canada  2016A000011124  Current prices
# ...         ...      ...             ...             ...
# 22880      2020  Nunavut     2016A000262  Current prices
# 22881      2020  Nunavut     2016A000262  Current prices
# 22882      2020  Nunavut     2016A000262  Current prices
# 22883      2020  Nunavut     2016A000262  Current prices
# 22884      2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# ...

# %%
prices = df

# %%
prices
# Out:
#        REF_DATE      GEO           DGUID          Prices  \
# 0          2007   Canada  2016A000011124  Current prices
# 1          2007   Canada  2016A000011124  Current prices
# 2          2007   Canada  2016A000011124  Current prices
# 3          2007   Canada  2016A000011124  Current prices
# 4          2007   Canada  2016A000011124  Current prices
# ...         ...      ...             ...             ...
# 22880      2020  Nunavut     2016A000262  Current prices
# 22881      2020  Nunavut     2016A000262  Current prices
# 22882      2020  Nunavut     2016A000262  Current prices
# 22883      2020  Nunavut     2016A000262  Current prices
# 22884      2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# ...

# %%
prices
# Out:
#        REF_DATE      GEO           DGUID          Prices  \
# 0          2007   Canada  2016A000011124  Current prices
# 1          2007   Canada  2016A000011124  Current prices
# 2          2007   Canada  2016A000011124  Current prices
# 3          2007   Canada  2016A000011124  Current prices
# 4          2007   Canada  2016A000011124  Current prices
# ...         ...      ...             ...             ...
# 22880      2020  Nunavut     2016A000262  Current prices
# 22881      2020  Nunavut     2016A000262  Current prices
# 22882      2020  Nunavut     2016A000262  Current prices
# 22883      2020  Nunavut     2016A000262  Current prices
# 22884      2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# ...

# %%
prices.isnull().sum()
# Out:
# REF_DATE       0
# GEO            0
# DGUID        345
# Prices         0
# Estimates      0
# VALUE        608
# dtype: int64

# %%
sns.heatmap(prices.corr(), annot=True)
plt.show()

# %%
taxes = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv")
# Out:
# C:\Users\amare\AppData\Local\Temp\ipykernel_32556\3104089031.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   taxes = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv")

# %%
taxes
# Out:
#        REF_DATE      GEO           DGUID                 Sales taxes  \
# 0          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 1          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 2          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 3          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 4          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# ...         ...      ...             ...                         ...
# 67615      2020  Nunavut     2016A000262       Excluding sales taxes
# 67616      2020  Nunavut     2016A000262       Excluding sales taxes
# 67617      2020  Nunavut     2016A000262       Excluding sales taxes
# 67618      2020  Nunavut     2016A000262       Excluding sales taxes
# 67619      2020  Nunavut     2016A000262       Excluding sales taxes
#
#                                                Estimates      UOM  UOM_ID  \
# ...

# %%
taxes.shape
# Out:
# (67620, 16)

# %%
taxes.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sales taxes', 'Estimates', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
taxes.nunique(axis=0)
# Out:
# REF_DATE            14
# GEO                 14
# DGUID               14
# Sales taxes          3
# Estimates          115
# UOM                  1
# UOM_ID               1
# SCALAR_FACTOR        1
# SCALAR_ID            1
# VECTOR            4830
# COORDINATE        4830
# VALUE            13208
# STATUS               1
# SYMBOL               0
# TERMINATED           0
# DECIMALS             1
# dtype: int64

# %%
taxes.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#            REF_DATE        UOM_ID     SCALAR_ID           VALUE    SYMBOL  \
# count  67620.000000  67620.000000  67620.000000    67158.000000  0.000000
# mean    2013.500000     81.000000      6.000000     1330.197604       nan
# std        4.031159      0.000000      0.000000    17618.550875       nan
# min     2007.000000     81.000000      6.000000   -44323.000000       nan
# 25%     2010.000000     81.000000      6.000000        0.100000       nan
# 50%     2013.500000     81.000000      6.000000        9.300000       nan
# 75%     2017.000000     81.000000      6.000000      125.700000       nan
# max     2020.000000     81.000000      6.000000  1230282.700000       nan
#
#       TERMINATED      DECIMALS
# count   0.000000  67620.000000
# mean         nan      1.000000
# std          nan      0.000000
# min          nan      1.000000
# 25%          nan      1.000000
# 50%          nan      1.000000
# 75%          nan      1.000000
# max          nan      1.000000

# %%
missing_values = [0]
taxes = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv", na_values = missing_values)
# Out:
# C:\Users\amare\AppData\Local\Temp\ipykernel_32556\4013242834.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   taxes = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\taxes.csv", na_values = missing_values)

# %%
 to_drop = ['SCALAR_ID',
           'VECTOR',
           'COORDINATE',
           'STATUS',
           'SYMBOL',
           'TERMINATED',
           'DECIMALS',
           'UOM',
           'UOM_ID',
           'SCALAR_FACTOR']

taxes.drop(to_drop, inplace=True, axis=1)

# %%
taxes
# Out:
#        REF_DATE      GEO           DGUID                 Sales taxes  \
# 0          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 1          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 2          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 3          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 4          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# ...         ...      ...             ...                         ...
# 67615      2020  Nunavut     2016A000262       Excluding sales taxes
# 67616      2020  Nunavut     2016A000262       Excluding sales taxes
# 67617      2020  Nunavut     2016A000262       Excluding sales taxes
# 67618      2020  Nunavut     2016A000262       Excluding sales taxes
# 67619      2020  Nunavut     2016A000262       Excluding sales taxes
#
#                                                Estimates    VALUE
# 0                Household final consumption expenditure  21569.3
# ...

# %%
taxes_new = taxes

# %%
taxes_new.isnull().sum()
# Out:
# REF_DATE           0
# GEO                0
# DGUID              0
# Sales taxes        0
# Estimates          0
# VALUE          15641
# dtype: int64

# %%
sns.heatmap(taxes_new.corr(), annot=True)
plt.show()

# %%
prices
# Out:
#        REF_DATE      GEO           DGUID          Prices  \
# 0          2007   Canada  2016A000011124  Current prices
# 1          2007   Canada  2016A000011124  Current prices
# 2          2007   Canada  2016A000011124  Current prices
# 3          2007   Canada  2016A000011124  Current prices
# 4          2007   Canada  2016A000011124  Current prices
# ...         ...      ...             ...             ...
# 22880      2020  Nunavut     2016A000262  Current prices
# 22881      2020  Nunavut     2016A000262  Current prices
# 22882      2020  Nunavut     2016A000262  Current prices
# 22883      2020  Nunavut     2016A000262  Current prices
# 22884      2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates     VALUE
# 0                Household final consumption expenditure  842029.0
# 1                       Food and non-alcoholic beverages   75232.0
# 2                                                   Food   66537.0
# ...

# %%
taxes
# Out:
#        REF_DATE      GEO           DGUID                 Sales taxes  \
# 0          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 1          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 2          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 3          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# 4          2007   Canada  2016A000011124  Provincial Sales Tax (PST)
# ...         ...      ...             ...                         ...
# 67615      2020  Nunavut     2016A000262       Excluding sales taxes
# 67616      2020  Nunavut     2016A000262       Excluding sales taxes
# 67617      2020  Nunavut     2016A000262       Excluding sales taxes
# 67618      2020  Nunavut     2016A000262       Excluding sales taxes
# 67619      2020  Nunavut     2016A000262       Excluding sales taxes
#
#                                                Estimates    VALUE
# 0                Household final consumption expenditure  21569.3
# ...

# %%
inner_merged_total = pd.merge(prices, taxes, on=["REF_DATE","GEO","DGUID","Estimates"])

# %%
inner_merged_total
# Out:
#        REF_DATE      GEO           DGUID          Prices  \
# 0          2007   Canada  2016A000011124  Current prices
# 1          2007   Canada  2016A000011124  Current prices
# 2          2007   Canada  2016A000011124  Current prices
# 3          2007   Canada  2016A000011124  Current prices
# 4          2007   Canada  2016A000011124  Current prices
# ...         ...      ...             ...             ...
# 67615      2020  Nunavut     2016A000262  Current prices
# 67616      2020  Nunavut     2016A000262  Current prices
# 67617      2020  Nunavut     2016A000262  Current prices
# 67618      2020  Nunavut     2016A000262  Current prices
# 67619      2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates   VALUE_x  \
# 0                Household final consumption expenditure  842029.0
# 1                Household final consumption expenditure  842029.0
# 2                Household final consumption expenditure  842029.0
# ...

# %%
inner_merged_total = inner_merged_total.rename(columns = {"REF_DATE":"Year","VALUE_x":"Price", "VALUE_y":"Taxes"})

# %%
inner_merged_total
# Out:
#        Year      GEO           DGUID          Prices  \
# 0      2007   Canada  2016A000011124  Current prices
# 1      2007   Canada  2016A000011124  Current prices
# 2      2007   Canada  2016A000011124  Current prices
# 3      2007   Canada  2016A000011124  Current prices
# 4      2007   Canada  2016A000011124  Current prices
# ...     ...      ...             ...             ...
# 67615  2020  Nunavut     2016A000262  Current prices
# 67616  2020  Nunavut     2016A000262  Current prices
# 67617  2020  Nunavut     2016A000262  Current prices
# 67618  2020  Nunavut     2016A000262  Current prices
# 67619  2020  Nunavut     2016A000262  Current prices
#
#                                                Estimates     Price  \
# 0                Household final consumption expenditure  842029.0
# 1                Household final consumption expenditure  842029.0
# 2                Household final consumption expenditure  842029.0
# ...

# %%
inner_merged_total.corr()
# Out:
#            Year     Price     Taxes
# Year   1.000000  0.016626  0.010627
# Price  0.016626  1.000000  0.610055
# Taxes  0.010627  0.610055  1.000000

# %%
sns.heatmap(inner_merged_total.corr(), annot=True)
plt.show()
