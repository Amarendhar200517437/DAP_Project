# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\amare\OneDrive\Desktop\datasets\\Final.csv")

# %%
df.head()
# Out:
#    REF_DATE     GEO           DGUID  \
# 0      2007  Canada  2016A000011124
# 1      2007  Canada  2016A000011124
# 2      2007  Canada  2016A000011124
# 3      2007  Canada  2016A000011124
# 4      2007  Canada  2016A000011124
#
#                                    Estimates  Provincial Sales Tax (PST)  \
# 0    Household final consumption expenditure                     21569.3
# 1           Food and non-alcoholic beverages                       647.1
# 2                                       Food                       432.9
# 3                    Non-alcoholic beverages                       214.2
# 4  Alcoholic beverages, tobacco and cannabis                      1334.8
#
#    Excluding sales taxes  Goods and Services Tax (GST)     Price      Total
# 0               796476.3                       23982.4  842029.0  1684057.0
# 1                73899.3                         685.5   75232.0   150463.9
# 2                65639.9                         464.2   66537.0   133074.0
# ...

# %%
df.tail()
# Out:
#        REF_DATE      GEO        DGUID  \
# 22535      2020  Nunavut  2016A000262
# 22536      2020  Nunavut  2016A000262
# 22537      2020  Nunavut  2016A000262
# 22538      2020  Nunavut  2016A000262
# 22539      2020  Nunavut  2016A000262
#
#                                                Estimates  \
# 22535                             Net expenditure abroad
# 22536                    Expenditure by Canadians abroad
# 22537  Expenditure by Canadians in other provinces or...
# 22538             Expenditure by non-residents in Canada
# 22539  Expenditure by Canadians residing in other pro...
#
#        Provincial Sales Tax (PST)  Excluding sales taxes  \
# 22535                         0.0                   13.4
# 22536                         0.0                    9.3
# 22537                         0.0                    8.1
# 22538                         0.0                   -0.5
# 22539                         0.0                   -3.5
#
# ...

# %%
df.shape
# Out:
# (22540, 9)

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Estimates', 'Provincial Sales Tax (PST)',
#        'Excluding sales taxes', 'Goods and Services Tax (GST)', 'Price',
#        'Total'],
#       dtype='object')

# %%
df.describe()
# Out:
#            REF_DATE  Provincial Sales Tax (PST)  Excluding sales taxes  \
# count  22540.000000                22386.000000           2.238600e+04
# mean    2013.500000                  118.230966           3.781275e+03
# std        4.031218                  991.129493           3.034377e+04
# min     2007.000000                    0.000000          -4.432300e+04
# 25%     2010.000000                    0.000000           2.080000e+01
# 50%     2013.500000                    0.800000           1.763000e+02
# 75%     2017.000000                   22.700000           1.151550e+03
# max     2020.000000                40382.300000           1.230283e+06
#
#        Goods and Services Tax (GST)         Price         Total
# count                  22386.000000  2.238600e+04  2.254000e+04
# mean                      91.087099  3.990589e+03  7.926652e+03
# std                      727.025848  3.195668e+04  6.369802e+04
# min                        0.000000 -4.432300e+04 -8.864600e+04
# ...

# %%
df.nunique(axis=0)
# Out:
# REF_DATE                           14
# GEO                                14
# DGUID                              14
# Estimates                         115
# Provincial Sales Tax (PST)       3148
# Excluding sales taxes           11436
# Goods and Services Tax (GST)     2955
# Price                            5763
# Total                           11821
# dtype: int64

# %%
df.isnull().sum()
# Out:
# REF_DATE                          0
# GEO                               0
# DGUID                             0
# Estimates                         0
# Provincial Sales Tax (PST)      154
# Excluding sales taxes           154
# Goods and Services Tax (GST)    154
# Price                           154
# Total                             0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# REF_DATE                        0
# GEO                             0
# DGUID                           0
# Estimates                       0
# Provincial Sales Tax (PST)      0
# Excluding sales taxes           0
# Goods and Services Tax (GST)    0
# Price                           0
# Total                           0
# dtype: int64

# %%
df
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2007   Canada  2016A000011124
# 1          2007   Canada  2016A000011124
# 2          2007   Canada  2016A000011124
# 3          2007   Canada  2016A000011124
# 4          2007   Canada  2016A000011124
# ...         ...      ...             ...
# 22535      2020  Nunavut     2016A000262
# 22536      2020  Nunavut     2016A000262
# 22537      2020  Nunavut     2016A000262
# 22538      2020  Nunavut     2016A000262
# 22539      2020  Nunavut     2016A000262
#
#                                                Estimates  \
# 0                Household final consumption expenditure
# 1                       Food and non-alcoholic beverages
# 2                                                   Food
# 3                                Non-alcoholic beverages
# 4              Alcoholic beverages, tobacco and cannabis
# ...                                                  ...
# 22535                             Net expenditure abroad
# ...

# %%
df = df.rename(columns = {"REF_DATE":"Year","GEO":"Location"})

# %%
df
# Out:
#        Year Location           DGUID  \
# 0      2007   Canada  2016A000011124
# 1      2007   Canada  2016A000011124
# 2      2007   Canada  2016A000011124
# 3      2007   Canada  2016A000011124
# 4      2007   Canada  2016A000011124
# ...     ...      ...             ...
# 22535  2020  Nunavut     2016A000262
# 22536  2020  Nunavut     2016A000262
# 22537  2020  Nunavut     2016A000262
# 22538  2020  Nunavut     2016A000262
# 22539  2020  Nunavut     2016A000262
#
#                                                Estimates  \
# 0                Household final consumption expenditure
# 1                       Food and non-alcoholic beverages
# 2                                                   Food
# 3                                Non-alcoholic beverages
# 4              Alcoholic beverages, tobacco and cannabis
# ...                                                  ...
# 22535                             Net expenditure abroad
# ...

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = df.drop(['DGUID'], axis=1)
test = df['Total']

# %%
df = plt.subplot(2,2,2, figsize=(10,4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 df = plt.subplot(2,2,2, figsize=(10,4))
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1283, in subplot(*args, **kwargs)
#    1280             break
#    1281 else:
#    1282     # we have exhausted the known Axes and none match, make a new one!
# -> 1283     ax = fig.add_subplot(*args, **kwargs)
#    1285 fig.sca(ax)
#    1287 bbox = ax.bbox
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:772, in FigureBase.add_subplot(self, *args, **kwargs)
#     769         args = tuple(map(int, str(args[0])))
#     770     projection_class, pkw = self._process_projection_requirements(
#     771         *args, **kwargs)
# --> 772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(test, test_size = 0.3, random_state = 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(test, test_size = 0.3, random_state = 2)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
regr = LinearRegression()

# %%
regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 regr.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined
